# %%
import pandas as pd

# %%
fifa = pd.read_csv('fifa.csv')
fifa
# Out:
#                                       Track name           Artist name  \
# 0                                    Island Life  Atomic Drum Assembly
# 1                                     Big Dreams                 Bakar
# 2                                    Jackie Chan                 Bantu
# 3                           Tribe (with J. Cole)                   Bas
# 4     Take It Easy (feat. U.S. Girls & Ledinsky)             BC Unidos
# ...                                          ...                   ...
# 1289      Work Song - Thievery Corporation Remix          Ray Barretto
# 1290                               Le Territoire       Brazilian Girls
# 1291            Mambo Mindoro - Hex Hector Remix            Cal Tjader
# 1292      Work Song - Thievery Corporation Remix          Ray Barretto
# 1293                               Chicachiquita           Thunderball
#
#                                                   Album  Playlist name  \
# ...

# %%
fifa = fifa.sort_values("Track name", ascending=True)
fifa.columns
# Out:
# Index(['Track name', ' Artist name', ' Album', ' Playlist name', ' Type',
#        ' ISRC'],
#       dtype='object')

# %%
fifa = fifa[fifa.duplicated(subset=['Track name'])].sort_values(
    "Track name", ascending=True)

# %%
pd.set_option('display.max_rows', 500)

# %%
fifa
# Out:
#                                              Track name  \
# 1244                                            Air War
# 237                                               Alive
# 148                                     All It Ever Was
# 380                       Atomizer - Pathaan's Dhol Mix
# 1176                      Back to the Pump - Radio Edit
# 995                           Be the One (with Kaskade)
# 617                                            Bodyrock
# 666                                              Brasil
# 1234                                             Brazil
# 1177                                              Broke
# 990                                             Bubblin
# 1233                                            Caminho
# 1238            Children of the Sun (feat. John Martin)
# 170                                              Cocoon
# 1186                           Come Again (feat. Giggs)
# 678                                Compliment Your Soul
# ...
