# %%
import csv
import pandas as pd
import matplotlib
mydict = {}

df=  pd.read_csv('song list.csv')

df



# idk what to do with this
# Out:
#                            Artist                                   Song  Game
# 0                       070 Shake                                 Morrow  2021
# 1                           Aitch                                   MICE  2021
# 2                 Alfie Templeman                     Wish I Was Younger  2021
# 3    Anitta, Myke Towers, Cardi B  Me Gusta (with Cardi B & Myke Towers)  2021
# 4                       Biig Piig                      Don't Turn Around  2021
# ..                            ...                                    ...   ...
# 764            The Crystal Method                        Keep Hope Alive  1998
# 765            The Crystal Method                                   More  1998
# 766            The Crystal Method         Now Is the Time (iCloud Remix)  1998
# 767            The Crystal Method                             Busy Child  1998
# 768            Electric Skychurch                             Hugga Bear  1998
#
# [769 rows x 3 columns]

# %%
df.head()
# Out:
#                          Artist                                   Song  Game
# 0                     070 Shake                                 Morrow  2021
# 1                         Aitch                                   MICE  2021
# 2               Alfie Templeman                     Wish I Was Younger  2021
# 3  Anitta, Myke Towers, Cardi B  Me Gusta (with Cardi B & Myke Towers)  2021
# 4                     Biig Piig                      Don't Turn Around  2021

# %%
splits = list(df.groupby("Game"))

# %%
# there has been 24 fifas. 
# for i in range(0,23):
#     print(splits[i][1])

# %%
splits[0][1] # first fifa aw
# Out:
#                  Artist                            Song  Game
# 763                Blur                          Song 2  1998
# 764  The Crystal Method                 Keep Hope Alive  1998
# 765  The Crystal Method                            More  1998
# 766  The Crystal Method  Now Is the Time (iCloud Remix)  1998
# 767  The Crystal Method                      Busy Child  1998
# 768  Electric Skychurch                      Hugga Bear  1998

# %%
splits[23][1] # last fifa
# Out:
#                                             Artist  \
# 0                                        070 Shake
# 1                                            Aitch
# 2                                  Alfie Templeman
# 3                     Anitta, Myke Towers, Cardi B
# 4                                        Biig Piig
# 5                                      Buju Banton
# 6                     Carlos Sadness, Bomba Estero
# 7                                          Celeste
# 8                                      Chloe Black
# 9                                           De Lux
# 10                                   Domino Saints
# 11                   Dua Lipa, The Blessed Madonna
# 12                                    Dylan Fraser
# 13  Everything Is Recorded, Infinite Coles, BERWYN
# 14                                     Fireboy DML
# 15                                   Glass Animals
# 16                                         ICEKIID
# ...

# %%
df.Artist.str.count("The Crystal Method").sum()
# Out:
# 4

# %%
df.plot.bar(title="cursed_graph", x='Artist' ,y='Game')
# Out:
# <AxesSubplot:title={'center':'cursed_graph'}, xlabel='Artist'>
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 48149 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54812 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 51652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 48149 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /home/codespace/.local/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 54812 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
